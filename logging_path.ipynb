# %%
import os
import pickle
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
log_dir = os.path.join(os.getcwd(), 'result/log')
image_dir = os.path.join(os.getcwd(), 'result/image')
ver = 'test'
top = 5
save = False

# %%
with open(os.path.join(log_dir, f'simulation_log_{ver}.pickle'), 'rb') as f:
    log_data = pickle.load(f)
print(len(log_data))
# Out:
# 1000

# %%
sorted_data = sorted(log_data.items(), key=(lambda x: x[1][1]), reverse=True)
len(sorted_data)
# Out:
# 1000

# %%
for i in range(100):
    print(len(sorted_data[i][1][0]), sorted_data[i][1][1])
# Out:
# 16 106.0644717004571
# 2 100.0
# 2 100.0
# 2 100.0
# 2 100.0
# 2 100.0
# 2 100.0
# 31 91.42391158275215
# 31 91.42391158275215
# 31 91.42391158275215
# 3 89.0
# 3 89.0
# 31 81.32391158275216
# 31 81.32391158275216
# 4 79.10000000000001
# 4 79.10000000000001
# 4 79.10000000000001
# 4 79.10000000000001
# 4 79.10000000000001
# 4 79.1
# 4 79.1
# 5 70.19000000000001
# 5 70.19
# 5 70.19
# 5 70.19
# 6 62.171000000000014
# 6 62.171000000000014
# 6 62.171000000000014
# 6 62.171000000000014
# 7 54.95390000000002
# 7 54.95390000000001
# 7 54.95390000000001
# 7 54.95390000000001
# 8 48.45851000000002
# 8 48.45851000000002
# 8 48.45851000000002
# 8 48.45851000000002
# 8 48.45851000000002
# 8 48.45851000000002
# 8 48.45851000000002
# 9 42.612659000000015
# 9 42.612659000000015
# 9 42.612659000000015
# 10 37.35139310000002
# 10 37.35139310000002
# 10 37.35139310000002
# 10 37.35139310000001
# 10 37.35139310000001
# 10 37.35139310000001
# 11 32.616253790000016
# 11 32.616253790000016
# 11 32.616253790000016
# 11 32.61625379000001
# 12 28.354628411000014
# 12 28.354628411000014
# 12 28.354628411000014
# 13 24.519165569900018
# 13 24.519165569900018
# 13 24.519165569900018
# 13 24.519165569900018
# 13 24.519165569900014
# 14 21.06724901291002
# 14 21.06724901291002
# 14 21.067249012910015
# 14 21.067249012910015
# 14 21.067249012910015
# 14 21.067249012910015
# 15 17.960524111619012
# 15 17.960524111619012
# 15 17.960524111619012
# 16 15.16447170045711
# 16 15.16447170045711
# 16 15.16447170045711
# 16 15.16447170045711
# 17 12.6480245304114
# 17 12.648024530411398
# 17 12.648024530411398
# 18 10.38322207737026
# 18 10.383222077370258
# 19 8.344899869633235
# 19 8.344899869633235
# 20 6.510409882669911
# 20 6.510409882669911
# 20 6.510409882669911
# 20 6.510409882669911
# 20 6.510409882669911
# 20 6.510409882669908
# 20 6.510409882669908
# 21 4.859368894402918
# 22 3.373432004962627
# 23 2.036088804466365
# 23 2.0360888044663645
# 24 0.8324799240197285
# 24 0.8324799240197285
# 24 0.8324799240197276
# 25 -0.25076806838224464
# 25 -0.2507680683822452
# 25 -0.2507680683822452
# 25 -0.2507680683822452
# 25 -0.2507680683822452

# %%
num_sucess = 0
for i in range(len(sorted_data)):
    if len(sorted_data[i][1][0]) < 31:
        num_sucess += 1
        data_as_array = np.array(sorted_data[i][1][0]).T
        plt.plot(data_as_array[0], data_as_array[1])
print("num_sucess:", num_sucess)
if save:
    plt.savefig(os.path.join(image_dir, f'simulation_path_sucess_{ver}.png'))
plt.show()
# Out:
# num_sucess: 105

# %%
for i in range(len(sorted_data)):
    data_as_array = np.array(sorted_data[i][1][0]).T
    plt.plot(data_as_array[0], data_as_array[1])
if save:
    plt.savefig(os.path.join(image_dir, f'simulation_path_all_{ver}.png'))
plt.show()

# %%
for i in range(top):
    data_as_array = np.array(sorted_data[i][1][0]).T
    plt.plot(data_as_array[0], data_as_array[1])
if save:
    plt.savefig(os.path.join(image_dir, f'simulation_path_top_{top}_{ver}.png'))
plt.show()

# %%
for i in range(len(sorted_data)):
    if len(sorted_data[i][1][0]) >= 3 and len(sorted_data[i][1][0]) < 4:
        data_as_array = np.array(sorted_data[i][1][0]).T
        plt.plot(data_as_array[0], data_as_array[1])
if save:
    plt.savefig(os.path.join(image_dir, f'simulation_path_3_{ver}.png'))
plt.show()
